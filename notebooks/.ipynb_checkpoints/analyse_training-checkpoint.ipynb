# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dir_in='../data/models'

# %%
experiment='baseline_mlp'
experiment='experiment_unet'


log=pd.read_csv(dir_in+'/'+experiment+'/train_log.csv')
log
log = log[['epoch','train/epoch_loss','val/epoch_loss','val/mse','val/accuracy']].dropna().set_index('epoch')
#log = log[~log.index.duplicated(keep='first')]
log = log.tail(20)

# %%
log.tail(1)
# Out:
#        train/epoch_loss  val/epoch_loss   val/mse  val/accuracy
# epoch
# 20.0           0.079162        0.081711  0.014726      0.883731

# %%
log
# Out:
#        train/epoch_loss  val/epoch_loss   val/mse  val/accuracy
# epoch
# 1.0            0.119059        0.103775  0.022599      0.851696
# 2.0            0.098883        0.098581  0.020461      0.860204
# 3.0            0.093637        0.093830  0.018717      0.865585
# 4.0            0.090520        0.091068  0.017659      0.869667
# 5.0            0.088490        0.089377  0.017234      0.873034
# ...                 ...             ...       ...           ...
# 16.0           0.569324        0.632042  0.113133      0.449729
# 17.0           0.591918        0.551628  0.087161      0.577480
# 18.0           0.562073        0.589293  0.110763      0.451175
# 19.0           0.587146        0.535085  0.077830      0.617727
# 20.0           0.564385        0.592863  0.110470      0.452725
#
# [70 rows x 4 columns]

# %%
log_og=log

# %%
plt.plot(log_og['train/epoch_loss'],ls='--',marker='o',label='train')
plt.plot(log_og['val/epoch_loss'],ls='--',marker='o',label='val')

plt.plot(log['train/epoch_loss'],marker='o',label='train')
plt.plot(log['val/epoch_loss'],marker='o',label='val')
plt.legend()
